# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulrajpr/AdvancedHyperParameterOptimisation/blob/ScikitOptimize/ScikitOptimize_RandomForestProcess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - Scikit Opt Random Forest Process - Optimizes the hyperparamers from the distribution of hyperparameter combinations based on the metric choosen using a random forest regressor
#
# - The guassian proces identify the local minima based on the number of iterations specified in the process
#
# - Steps
#
# 1. define the model
# 2. define parameter space
# 3. define objective function
# 4. run the search with dummy_minimize class

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import load_breast_cancer

# %%
dataset = load_breast_cancer()
data = dataset.data
columns = dataset.feature_names
df = pd.DataFrame(data = data, columns = columns)
df['target'] = dataset.target
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
#  13  area error               569 non-null    float64
#  14  smoothness error         569 non-null    float64
#  15  compactness error        569 non-null    float64
#  16  concavity error          569 non-null    float64
#  17  concave points error     569 non-null    float64
#  18  symmetry error           569 non-null    float64
#  19  fractal dimension error  569 non-null    float64
#  20  worst radius             569 non-null    float64
#  21  worst texture            569 non-null    float64
#  22  worst perimeter          569 non-null    float64
#  23  worst area               569 non-null    float64
#  24  worst smoothness         569 non-null    float64
#  25  worst compactness        569 non-null    float64
#  26  worst concavity          569 non-null    float64
#  27  worst concave points     569 non-null    float64
#  28  worst symmetry           569 non-null    float64
#  29  worst fractal dimension  569 non-null    float64
#  30  target                   569 non-null    int64
# dtypes: float64(30), int64(1)
# memory usage: 137.9 KB

# %%
X = df.drop('target', axis =1)
y = df['target']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train,y_test = train_test_split(X,y,train_size = 0.7, random_state = 100, stratify = y)

# %% [markdown]
# Define the model object

# %%
from xgboost import XGBClassifier

# %%
# non-skleran model object
xgb = XGBClassifier(random_state = 100)

# %% [markdown]
# Parameter list --
#
# max_depth: int = 3, learning_rate: float = 0.1, n_estimators: int = 100, verbosity: int = 1, silent: Any | None = None, objective: str = "binary:logistic", booster: str = 'gbtree', n_jobs: int = 1, nthread: Any | None = None, gamma: int = 0, min_child_weight: int = 1, max_delta_step: int = 0, subsample: int = 1, colsample_bytree: int = 1, colsample_bylevel: int = 1, colsample_bynode: int = 1, reg_alpha: int = 0, reg_lambda: int = 1, scale_pos_weight: int = 1, base_score: float = 0.5, random_state: int = 0, seed: Any | None = None, missing: Any | None = None, **kwargs: Any) -> None
# Implementation of the scikit-learn API for XGBoost classification.

# %% [markdown]
# Define the parameter space

# %%
# !pip install scikit-optimize
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 11.0 MB/s
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.8/dist-packages (from scikit-optimize) (1.0.2)
# Collecting pyaml>=16.9
#   Downloading pyaml-21.10.1-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.8/dist-packages (from scikit-optimize) (1.7.3)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.8/dist-packages (from scikit-optimize) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-optimize) (1.2.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from pyaml>=16.9->scikit-optimize) (6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.20.0->scikit-optimize) (3.1.0)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-21.10.1 scikit-optimize-0.9.0

# %%
from skopt.space import Integer,Real,Categorical

# %%
params_grid = [Integer(low = 10, high = 120, prior = 'uniform', name = 'n_estimators'),
          Integer(low = 1, high = 8, prior = 'uniform', name = 'max_depth'),
          Real(low = 0.001, high = 0.1, prior = 'log-uniform', name = 'learning_rate'),
          Real(low = 0.001, high = 0.999, prior = 'log-uniform', name = 'min_samples_splits'),
          Categorical(['exponential','deviance'], name = 'loss')]

# %% [markdown]
# create the objective function

# %%
from skopt.utils import use_named_args

# %%
from sklearn.model_selection import cross_val_score

# %%
@use_named_args(params_grid)
def objective(**params):

  xgb.set_params(**params)

  scores = cross_val_score(estimator = xgb,
                           X = X_train,
                           y = y_train,
                           scoring = 'accuracy',
                           cv = 5,
                           n_jobs = -1)
  
  mean_score = np.mean(scores)
  return -mean_score

# %% [markdown]
# Run the search using the forest_minimize

# %%
from skopt import forest_minimize

# %%
forest_ = forest_minimize(func = objective,
                          dimensions = params_grid,
                          base_estimator = 'RF',
                          n_calls = 50,
                          n_initial_points = 5,
                          acq_func = 'EI',
                          verbose = 1, 
                          random_state = 100)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 1.2016
# Function value obtained: -0.9346
# Current minimum: -0.9346
# Iteration No: 2 started. Evaluating function at random point.
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 0.1691
# Function value obtained: -0.9297
# Current minimum: -0.9346
# Iteration No: 3 started. Evaluating function at random point.
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 0.1352
# Function value obtained: -0.9497
# Current minimum: -0.9497
# Iteration No: 4 started. Evaluating function at random point.
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 0.0953
# Function value obtained: -0.9371
# Current minimum: -0.9497
# Iteration No: 5 started. Evaluating function at random point.
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.2250
# Function value obtained: -0.9396
# Current minimum: -0.9497
# Iteration No: 6 started. Searching for the next optimal point.
# Iteration No: 6 ended. Search finished for the next optimal point.
# Time taken: 0.2862
# Function value obtained: -0.9472
# Current minimum: -0.9497
# Iteration No: 7 started. Searching for the next optimal point.
# Iteration No: 7 ended. Search finished for the next optimal point.
# Time taken: 0.2797
# Function value obtained: -0.9295
# Current minimum: -0.9497
# Iteration No: 8 started. Searching for the next optimal point.
# Iteration No: 8 ended. Search finished for the next optimal point.
# Time taken: 0.2992
# Function value obtained: -0.9522
# Current minimum: -0.9522
# Iteration No: 9 started. Searching for the next optimal point.
# Iteration No: 9 ended. Search finished for the next optimal point.
# Time taken: 0.3930
# Function value obtained: -0.9547
# Current minimum: -0.9547
# Iteration No: 10 started. Searching for the next optimal point.
# Iteration No: 10 ended. Search finished for the next optimal point.
# Time taken: 0.2601
# Function value obtained: -0.9497
# Current minimum: -0.9547
# Iteration No: 11 started. Searching for the next optimal point.
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 0.3390
# Function value obtained: -0.9371
# Current minimum: -0.9547
# Iteration No: 12 started. Searching for the next optimal point.
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 0.3357
# Function value obtained: -0.9497
# Current minimum: -0.9547
# Iteration No: 13 started. Searching for the next optimal point.
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 0.2190
# Function value obtained: -0.9422
# Current minimum: -0.9547
# Iteration No: 14 started. Searching for the next optimal point.
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 0.5083
# Function value obtained: -0.9296
# Current minimum: -0.9547
# Iteration No: 15 started. Searching for the next optimal point.
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 0.5251
# Function value obtained: -0.9472
# Current minimum: -0.9547
# Iteration No: 16 started. Searching for the next optimal point.
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 0.4126
# Function value obtained: -0.9597
# Current minimum: -0.9597
# Iteration No: 17 started. Searching for the next optimal point.
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 0.3530
# Function value obtained: -0.9522
# Current minimum: -0.9597
# Iteration No: 18 started. Searching for the next optimal point.
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 0.3957
# Function value obtained: -0.9572
# Current minimum: -0.9597
# Iteration No: 19 started. Searching for the next optimal point.
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 0.2949
# Function value obtained: -0.9497
# Current minimum: -0.9597
# Iteration No: 20 started. Searching for the next optimal point.
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 0.3939
# Function value obtained: -0.9647
# Current minimum: -0.9647
# Iteration No: 21 started. Searching for the next optimal point.
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 0.3073
# Function value obtained: -0.9598
# Current minimum: -0.9647
# Iteration No: 22 started. Searching for the next optimal point.
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 0.3484
# Function value obtained: -0.9597
# Current minimum: -0.9647
# Iteration No: 23 started. Searching for the next optimal point.
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 0.2380
# Function value obtained: -0.9295
# Current minimum: -0.9647
# Iteration No: 24 started. Searching for the next optimal point.
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 0.2555
# Function value obtained: -0.9396
# Current minimum: -0.9647
# Iteration No: 25 started. Searching for the next optimal point.
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 0.3611
# Function value obtained: -0.9597
# Current minimum: -0.9647
# Iteration No: 26 started. Searching for the next optimal point.
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 0.2835
# Function value obtained: -0.9522
# Current minimum: -0.9647
# Iteration No: 27 started. Searching for the next optimal point.
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 0.5758
# Function value obtained: -0.9497
# Current minimum: -0.9647
# Iteration No: 28 started. Searching for the next optimal point.
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 0.6164
# Function value obtained: -0.9522
# Current minimum: -0.9647
# Iteration No: 29 started. Searching for the next optimal point.
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 0.3953
# Function value obtained: -0.9572
# Current minimum: -0.9647
# Iteration No: 30 started. Searching for the next optimal point.
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 0.3386
# Function value obtained: -0.9522
# Current minimum: -0.9647
# Iteration No: 31 started. Searching for the next optimal point.
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 0.2691
# Function value obtained: -0.9497
# Current minimum: -0.9647
# Iteration No: 32 started. Searching for the next optimal point.
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 0.5617
# Function value obtained: -0.9472
# Current minimum: -0.9647
# Iteration No: 33 started. Searching for the next optimal point.
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 0.3247
# Function value obtained: -0.9647
# Current minimum: -0.9647
# Iteration No: 34 started. Searching for the next optimal point.
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 0.3096
# Function value obtained: -0.9623
# Current minimum: -0.9647
# Iteration No: 35 started. Searching for the next optimal point.
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 0.3949
# Function value obtained: -0.9622
# Current minimum: -0.9647
# Iteration No: 36 started. Searching for the next optimal point.
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 0.2700
# Function value obtained: -0.9497
# Current minimum: -0.9647
# Iteration No: 37 started. Searching for the next optimal point.
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 0.3845
# Function value obtained: -0.9447
# Current minimum: -0.9647
# Iteration No: 38 started. Searching for the next optimal point.
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 0.4587
# Function value obtained: -0.9547
# Current minimum: -0.9647
# Iteration No: 39 started. Searching for the next optimal point.
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 0.3164
# Function value obtained: -0.9597
# Current minimum: -0.9647
# Iteration No: 40 started. Searching for the next optimal point.
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 0.3072
# Function value obtained: -0.9522
# Current minimum: -0.9647
# Iteration No: 41 started. Searching for the next optimal point.
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 0.3035
# Function value obtained: -0.9547
# Current minimum: -0.9647
# Iteration No: 42 started. Searching for the next optimal point.
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 0.2944
# Function value obtained: -0.9497
# Current minimum: -0.9647
# Iteration No: 43 started. Searching for the next optimal point.
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 0.2747
# Function value obtained: -0.9572
# Current minimum: -0.9647
# Iteration No: 44 started. Searching for the next optimal point.
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 0.2685
# Function value obtained: -0.9471
# Current minimum: -0.9647
# Iteration No: 45 started. Searching for the next optimal point.
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 0.2560
# Function value obtained: -0.9295
# Current minimum: -0.9647
# Iteration No: 46 started. Searching for the next optimal point.
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 0.2931
# Function value obtained: -0.9547
# Current minimum: -0.9647
# Iteration No: 47 started. Searching for the next optimal point.
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 0.2598
# Function value obtained: -0.9497
# Current minimum: -0.9647
# Iteration No: 48 started. Searching for the next optimal point.
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 0.3543
# Function value obtained: -0.9522
# Current minimum: -0.9647
# Iteration No: 49 started. Searching for the next optimal point.
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 0.2911
# Function value obtained: -0.9547
# Current minimum: -0.9647
# Iteration No: 50 started. Searching for the next optimal point.
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 0.3566
# Function value obtained: -0.9572
# Current minimum: -0.9647

# %% [markdown]
# Explore the search results

# %%
# accuracy
forest_.fun
# Out:
# -0.9647468354430379

# %%
# best parameters
forest_.x
# Out:
# [77, 6, 0.0792012400597365, 0.017677385905539564, 'deviance']

# %%
hyper_parameters = ['n_estimators','max_depth','learning_rate','min_samples_split','loss']

# %%
# hyperparameter combinations
forest_.x_iters
# Out:
# [[34, 4, 0.00666949262740574, 0.03792439690094259, 'exponential'],
#  [62, 3, 0.00236012152786367, 0.004268073925417127, 'exponential'],
#  [34, 8, 0.06062390517439188, 0.0042414608781566, 'exponential'],
#  [19, 6, 0.0027503944643483894, 0.8618786655442375, 'deviance'],
#  [11, 6, 0.042899230036160536, 0.0066389921151654525, 'exponential'],
#  [77, 2, 0.02212585713892033, 0.004503767339111197, 'exponential'],
#  [23, 1, 0.08431720112892338, 0.026533927118860854, 'exponential'],
#  [38, 8, 0.08334075016936701, 0.00453462801583194, 'deviance'],
#  [81, 7, 0.06636606894561335, 0.0021223596107795136, 'deviance'],
#  [23, 8, 0.07158843522750774, 0.001446652113580619, 'exponential'],
#  [50, 7, 0.001614640291229373, 0.004308413267215112, 'exponential'],
#  [107, 2, 0.09146434281794638, 0.001410892277543259, 'exponential'],
#  [14, 2, 0.08408353794647283, 0.003070915886672352, 'exponential'],
#  [105, 8, 0.001798464333382856, 0.0021878945708930404, 'exponential'],
#  [108, 8, 0.012240810022927609, 0.002094437063424637, 'exponential'],
#  [87, 8, 0.08036052880439125, 0.02213181473553918, 'exponential'],
#  [62, 8, 0.09818988256410176, 0.05127008977500146, 'exponential'],
#  [40, 7, 0.07587202017927076, 0.19075091582157191, 'deviance'],
#  [30, 7, 0.07573329163565187, 0.0250188103506995, 'exponential'],
#  [77, 6, 0.0792012400597365, 0.017677385905539564, 'deviance'],
#  [118, 1, 0.07808541214896748, 0.027553066026153455, 'deviance'],
#  [62, 4, 0.08083746308825712, 0.035858539644574645, 'deviance'],
#  [37, 1, 0.07746177851072648, 0.5448647059020495, 'deviance'],
#  [49, 1, 0.07897934195502596, 0.06691046263929173, 'deviance'],
#  [60, 4, 0.08148887335837315, 0.20349595115959598, 'deviance'],
#  [78, 1, 0.07583896132345579, 0.020649637206750292, 'deviance'],
#  [55, 1, 0.08100278733394085, 0.7305747203621589, 'deviance'],
#  [86, 6, 0.009315970472986225, 0.024152922886908533, 'deviance'],
#  [41, 5, 0.08431844507991354, 0.0317349299743289, 'deviance'],
#  [37, 5, 0.07944231763525067, 0.34891756878896246, 'deviance'],
#  [60, 1, 0.07998217647907006, 0.4916018580277322, 'deviance'],
#  [113, 7, 0.007917776484772272, 0.027073854792945017, 'deviance'],
#  [36, 4, 0.08031623012816565, 0.11072462798019278, 'deviance'],
#  [35, 4, 0.0795862908370984, 0.12547033109146621, 'exponential'],
#  [76, 4, 0.0771247875006242, 0.07196043928231309, 'deviance'],
#  [18, 4, 0.08077675716384464, 0.03791527011722284, 'exponential'],
#  [63, 4, 0.007643835794533789, 0.13860585750990054, 'deviance'],
#  [68, 4, 0.07759420287823651, 0.8077862460235972, 'exponential'],
#  [47, 3, 0.07990909171351157, 0.13262913724262798, 'exponential'],
#  [43, 3, 0.07797857136947224, 0.042068400037250826, 'exponential'],
#  [36, 3, 0.08030835723789706, 0.1976400786576068, 'deviance'],
#  [21, 7, 0.07914644075327905, 0.07914344654695692, 'deviance'],
#  [27, 3, 0.07952519728397402, 0.1031886396592486, 'deviance'],
#  [18, 4, 0.09345065202727088, 0.12503353123726296, 'deviance'],
#  [42, 1, 0.07970007743347743, 0.041007029932497496, 'exponential'],
#  [50, 2, 0.08124636887473716, 0.16891495836792733, 'deviance'],
#  [27, 2, 0.07968979312516777, 0.10796341364805696, 'exponential'],
#  [36, 2, 0.08016514395298445, 0.036614497214721604, 'deviance'],
#  [75, 1, 0.0782719177046648, 0.011236654690715015, 'deviance'],
#  [54, 4, 0.07744266543575859, 0.123648224660659, 'deviance']]

# %%
# accuracy (metric) in each iterations
forest_.func_vals
# Out:
# array([-0.93462025, -0.92968354, -0.9496519 , -0.93712025, -0.93958861,
#        -0.9471519 , -0.92952532, -0.95221519, -0.95471519, -0.94968354,
#        -0.93712025, -0.9496519 , -0.9421519 , -0.92955696, -0.9471519 ,
#        -0.95971519, -0.95218354, -0.95721519, -0.94968354, -0.96474684,
#        -0.95977848, -0.95971519, -0.92952532, -0.93962025, -0.95971519,
#        -0.95224684, -0.94971519, -0.95218354, -0.95721519, -0.95221519,
#        -0.94971519, -0.9471519 , -0.96474684, -0.96227848, -0.96221519,
#        -0.9496519 , -0.9446519 , -0.95468354, -0.95971519, -0.95218354,
#        -0.95471519, -0.94968354, -0.95724684, -0.94712025, -0.92952532,
#        -0.95471519, -0.9496519 , -0.9521519 , -0.95474684, -0.95721519])

# %%
hyper_combo = pd.DataFrame(forest_.x_iters)
metric = pd.DataFrame(abs(forest_.func_vals))
tmp = pd.concat([hyper_combo,metric], axis = 1)
tmp.columns = hyper_parameters + ['metric']
tmp.sort_values(by = 'metric', ascending = False, inplace = True)
tmp.head()
# Out:
#     n_estimators  max_depth  learning_rate  min_samples_split         loss  \
# 32            36          4       0.080316           0.110725     deviance
# 19            77          6       0.079201           0.017677     deviance
# 33            35          4       0.079586           0.125470  exponential
# 34            76          4       0.077125           0.071960     deviance
# 20           118          1       0.078085           0.027553     deviance
#
#       metric
# 32  0.964747
# 19  0.964747
# 33  0.962278
# 34  0.962215
# 20  0.959778

# %%
best_params = tmp.drop('metric', axis = 1).iloc[0,:].to_dict()
best_params
# Out:
# {'n_estimators': 36,
#  'max_depth': 4,
#  'learning_rate': 0.08031623012816565,
#  'min_samples_split': 0.11072462798019278,
#  'loss': 'deviance'}

# %% [markdown]
# Lets Explor the convergence, evalations plots

# %%
from skopt.plots import plot_convergence,plot_evaluations,plot_objective

# %%
plot_convergence(forest_)
plt.show()

# %%
plot_evaluations(forest_)
plt.show()

# %%
plot_objective(forest_)
plt.show()

# %% [markdown]
# Generate the final model

# %%
model = XGBClassifier(n_estimators = best_params['n_estimators'],
                      max_depth = best_params['max_depth'],
                      min_samples_split = best_params['min_samples_split'],
                      learning_rate = best_params['learning_rate'],
                      loss = best_params['loss'])

# %%
model.get_xgb_params
# Out:
# <bound method XGBModel.get_xgb_params of XGBClassifier(learning_rate=0.08031623012816565, loss='deviance', max_depth=4,
#               min_samples_split=0.11072462798019278, n_estimators=36)>

# %%
model.fit(X_train,y_train)
# Out:
# XGBClassifier(learning_rate=0.08031623012816565, loss='deviance', max_depth=4,
#               min_samples_split=0.11072462798019278, n_estimators=36)

# %% [markdown]
# Evaluate the final model

# %%
from sklearn.metrics import accuracy_score

# %%
print('train accuracy : ',accuracy_score(y_train,model.predict(X_train)))
print('test accuracy : ',accuracy_score(y_test,model.predict(X_test)))
# Out:
# train accuracy :  0.9949748743718593
# test accuracy :  0.9707602339181286
